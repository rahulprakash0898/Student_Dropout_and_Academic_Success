# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import plotly as px

# %% [markdown]
# # Read the data

# %%
Student=pd.read_csv("E:\\Rahul\\A.I.F\\Python\\Student Dropout & Academic Success.csv")

# %% [markdown]
# #  Data Cleaning

# %%
Student.head()
# Out:
#    Marital status  Application mode  Application order  Course
# 0               1                 8                  5       2  \
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality
# 0                           1                       1            1  \
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...
# 0                      13                      10                    6  ...  \
# ...

# %%
Student.tail()
# Out:
#       Marital status  Application mode  Application order  Course
# 4419               1                 1                  6      15  \
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nacionality
# 4419                           1                       1            1  \
# 4420                           1                       1           19
# 4421                           1                       1            1
# 4422                           1                       1            1
# 4423                           1                       1            9
#
#       Mother's qualification  Father's qualification  Mother's occupation
# ...

# %%
Student[34:56]
# Out:
#     Marital status  Application mode  Application order  Course
# 34               1                 1                  1      17  \
# 35               1                12                  1       1
# 36               1                12                  1       7
# 37               1                14                  1       9
# 38               4                12                  1      17
# 39               1                15                  1       8
# 40               1                 1                  5      15
# 41               1                 1                  2       9
# 42               1                 1                  6      12
# 43               1                 8                  1      15
# 44               1                12                  1      17
# 45               1                 8                  1      17
# 46               1                 8                  2      10
# 47               1                 8                  6      12
# ...

# %%
Student.shape
# Out:
# (4424, 35)

# %%
Student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
# ...

# %%
Student.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Educational special needs', 'Debtor', 'Tuition fees up to date',
#        'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
# ...

# %%
Student.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# ...

# %%
Student.describe(include='all')
# Out:
#         Marital status  Application mode  Application order       Course
# count      4424.000000       4424.000000        4424.000000  4424.000000  \
# unique             NaN               NaN                NaN          NaN
# top                NaN               NaN                NaN          NaN
# freq               NaN               NaN                NaN          NaN
# mean          1.178571          6.886980           1.727848     9.899186
# std           0.605747          5.298964           1.313793     4.331792
# min           1.000000          1.000000           0.000000     1.000000
# 25%           1.000000          1.000000           1.000000     6.000000
# 50%           1.000000          8.000000           1.000000    10.000000
# 75%           1.000000         12.000000           2.000000    13.000000
# max           6.000000         18.000000           9.000000    17.000000
#
#         Daytime/evening attendance  Previous qualification  Nacionality
# ...

# %%
my_list=list(Student)

# %%
print(my_list)
# Out:
# ['Marital status', 'Application mode', 'Application order', 'Course', 'Daytime/evening attendance', 'Previous qualification', 'Nacionality', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'Age at enrollment', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP', 'Target']

# %% [markdown]
# # Analysis of Data

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=Student, x='Target', order=Student['Target'].value_counts().index)
plt.title('Distribution of Target Variable')
plt.show()

# %% [markdown]
# # Marital status

# %%
# Define the figure size
plt.figure(figsize=(20, 15))

plt.subplot(231)
sns.countplot(data=Student, x='Marital status')
plt.title('Marital Status Distribution')
# Out:
# Text(0.5, 1.0, 'Marital Status Distribution')

# %% [markdown]
# # Course

# %%
# Define the figure size
plt.figure(figsize=(20, 15))

plt.subplot(232)
sns.countplot(data=Student, x='Course')
plt.title('Course Distribution')
# Out:
# Text(0.5, 1.0, 'Course Distribution')

# %% [markdown]
# # Age at enrollment

# %%
# Define the figure size
plt.figure(figsize=(20, 15))

plt.subplot(233)
sns.histplot(data=Student, x='Age at enrollment', bins=30, kde=True)
plt.title('Age at Enrollment Distribution')
# Out:
# Text(0.5, 1.0, 'Age at Enrollment Distribution')

# %% [markdown]
# # Gender

# %%
# Define the figure size
plt.figure(figsize=(20, 15))

plt.subplot(234)
sns.countplot(data=Student, x='Gender')
plt.title('Gender Distribution')
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %% [markdown]
# # Unemployment rate

# %%
# Define the figure size
plt.figure(figsize=(20, 15))

plt.subplot(235)
sns.histplot(data=Student, x='Unemployment rate', bins=30, kde=True)
plt.title('Unemployment Rate Distribution')
# Out:
# Text(0.5, 1.0, 'Unemployment Rate Distribution')

# %% [markdown]
# # Bivariate analysis

# %% [markdown]
# # Marital status vs Target

# %% [markdown]
# # Histogram

# %%
# Define the figure size
plt.figure(figsize=(20, 20))

plt.subplot(321)
Student.groupby(['Marital status', 'Target']).size().unstack().plot(kind='bar', stacked=True, ax=plt.gca())
plt.title('Marital Status vs Target')
# Out:
# Text(0.5, 1.0, 'Marital Status vs Target')

# %% [markdown]
# # Pie-Chart

# %%
plt.figure(figsize=(10,10))
plt.pie(list(Student[['Marital status','Target']].value_counts())[0:11],labels=list(Student[['Marital status','Target']].value_counts().keys())[0:11],autopct='%0.1f%%',startangle=90,
       counterclock=False)
plt.show()

# %% [markdown]
# # Course vs Target

# %% [markdown]
# # Histogram

# %%
# Define the figure size
plt.figure(figsize=(20, 20))

plt.subplot(322)
Student.groupby(['Course', 'Target']).size().unstack().plot(kind='bar', stacked=True, ax=plt.gca())
plt.title('Course vs Target')
# Out:
# Text(0.5, 1.0, 'Course vs Target')

# %% [markdown]
# # Pie-Chart

# %%
plt.figure(figsize=(10,10))
plt.pie(list(Student[['Course','Target']].value_counts())[0:11],labels=list(Student[['Course','Target']].value_counts().keys())[0:11],autopct='%0.1f%%',startangle=90,
       counterclock=False)
plt.show()

# %% [markdown]
# # Age at enrollment vs Target

# %%
# Define the figure size
plt.figure(figsize=(20, 20))

plt.subplot(323)
sns.boxplot(data=Student, x='Target', y='Age at enrollment')
plt.title('Age at Enrollment vs Target')
# Out:
# Text(0.5, 1.0, 'Age at Enrollment vs Target')

# %% [markdown]
# # Gender vs Target

# %%
# Define the figure size
plt.figure(figsize=(20, 20))

plt.subplot(324)
Student.groupby(['Gender', 'Target']).size().unstack().plot(kind='bar', stacked=True, ax=plt.gca())
plt.title('Gender vs Target')
# Out:
# Text(0.5, 1.0, 'Gender vs Target')

# %% [markdown]
# # Pie-Chart

# %%
plt.figure(figsize=(10,10))
plt.pie(list(Student[['Gender','Target']].value_counts())[0:11],labels=list(Student[['Gender','Target']].value_counts().keys())[0:11],autopct='%0.1f%%',startangle=90,
       counterclock=False)
plt.show()

# %% [markdown]
# # Unemployment rate vs Target

# %%
# Define the figure size
plt.figure(figsize=(20, 20))

plt.subplot(325)
sns.boxplot(data=Student, x='Target', y='Unemployment rate')
plt.title('Unemployment Rate vs Target')
# Out:
# Text(0.5, 1.0, 'Unemployment Rate vs Target')

# %% [markdown]
# # Identify categorical and numerical columns

# %%
categorical_cols = [col for col in Student.columns if Student[col].nunique() <= 20 and col != 'Target']
numerical_cols = [col for col in Student.columns if Student[col].nunique() > 20 and col != 'Target']

categorical_cols, numerical_cols
# Out:
# (['Marital status',
#   'Application mode',
#   'Application order',
#   'Course',
#   'Daytime/evening attendance',
#   'Previous qualification',
#   'Displaced',
#   'Educational special needs',
#   'Debtor',
#   'Tuition fees up to date',
#   'Gender',
#   'Scholarship holder',
#   'International',
#   'Curricular units 1st sem (without evaluations)',
#   'Curricular units 2nd sem (credited)',
#   'Curricular units 2nd sem (approved)',
#   'Curricular units 2nd sem (without evaluations)',
#   'Unemployment rate',
#   'Inflation rate',
#   'GDP'],
#  ['Nacionality',
#   "Mother's qualification",
#   "Father's qualification",
#   "Mother's occupation",
#   "Father's occupation",
#   'Age at enrollment',
#   'Curricular units 1st sem (credited)',
#   'Curricular units 1st sem (enrolled)',
#   'Curricular units 1st sem (evaluations)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 2nd sem (enrolled)',
# ...

# %% [markdown]
# # One-hot encode the categorical columns

# %%
df_encoded = pd.get_dummies(Student, columns=categorical_cols)

# Display the first few rows of the encoded dataset
df_encoded.head()
# Out:
#    Nacionality  Mother's qualification  Father's qualification
# 0            1                      13                      10  \
# 1            1                       1                       3
# 2            1                      22                      27
# 3            1                      23                      27
# 4            1                      22                      28
#
#    Mother's occupation  Father's occupation  Age at enrollment
# 0                    6                   10                 20  \
# 1                    4                    4                 19
# 2                   10                   10                 19
# 3                    6                    4                 20
# 4                   10                   10                 45
#
#    Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)
# 0                                    0                                    0  \
# ...

# %% [markdown]
# # Define the features and the target

# %%
from sklearn.model_selection import train_test_split

X = df_encoded.drop('Target', axis=1)
y = df_encoded['Target']

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Check the shape of the training and test sets
X_train.shape, X_test.shape
# Out:
# ((3096, 185), (1328, 185))

# %% [markdown]
# # Calculate the accuracy of the model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Initialize a Random Forest classifier
rf = RandomForestClassifier(random_state=42)

# Train the classifier
rf.fit(X_train, y_train)

# Predict on the test set
y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

accuracy
# Out:
# 0.766566265060241

# %% [markdown]
# # Get the best parameters and the best accuracy score

# %%
from sklearn.model_selection import GridSearchCV

# Define the grid of hyperparameters
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [10, 20, None]
}

# Initialize a GridSearchCV object
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, scoring='accuracy')

# Perform the grid search
grid_search.fit(X_train, y_train)

# Get the best parameters and the best accuracy score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

best_params, best_score
# Out:
# ({'max_depth': 20, 'n_estimators': 100}, 0.7703488372093025)

# %% [markdown]
# # Calculate the accuracy of the best model

# %%
# Predict on the test set with the best model
y_pred_best = grid_search.predict(X_test)

accuracy_best = accuracy_score(y_test, y_pred_best)

accuracy_best
# Out:
# 0.7710843373493976

# %% [markdown]
# # Calculate multiclass AUC-ROC

# %%
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.preprocessing import LabelBinarizer

# Calculate precision, recall, and F1 score
classification_metrics = classification_report(y_test, y_pred_best, output_dict=True)

# We need to binarize the labels for the multiclass AUC-ROC
lb = LabelBinarizer()
lb.fit(y_test)
y_test_lb = lb.transform(y_test)
y_pred_lb = lb.transform(y_pred_best)

roc_auc_multiclass = roc_auc_score(y_test_lb, y_pred_lb, multi_class='ovr')

classification_metrics, roc_auc_multiclass
# Out:
# ({'Dropout': {'precision': 0.8061224489795918,
#    'recall': 0.7400468384074942,
#    'f1-score': 0.7716727716727717,
#    'support': 427},
#   'Enrolled': {'precision': 0.5882352941176471,
#    'recall': 0.33613445378151263,
#    'f1-score': 0.42780748663101603,
#    'support': 238},
#   'Graduate': {'precision': 0.785,
#    'recall': 0.947209653092006,
#    'f1-score': 0.8585099111414901,
#    'support': 663},
#   'accuracy': 0.7710843373493976,
#   'macro avg': {'precision': 0.726452581032413,
#    'recall': 0.6744636484270042,
#    'f1-score': 0.685996723148426,
#    'support': 1328},
#   'weighted avg': {'precision': 0.7565280765920827,
#    'recall': 0.7710843373493976,
#    'f1-score': 0.7533994927780596,
#    'support': 1328}},
#  0.7715029100883375)

# %% [markdown]
# # Plot the top 10 most important features

# %%
# Get feature importances
importances = grid_search.best_estimator_.feature_importances_

# Convert the importances into a DataFrame
feature_importances = pd.DataFrame({"feature": X_train.columns, "importance": importances})

# Sort the DataFrame by importance
feature_importances = feature_importances.sort_values("importance", ascending=False)

# Display the top 10 most important features
feature_importances_top10 = feature_importances.head(10)

plt.figure(figsize=(10, 8))
sns.barplot(data=feature_importances_top10, x='importance', y='feature')
plt.title('Top 10 Most Important Features')
plt.show()

# %% [markdown]
# # Display the student's data

# %%
# Select a random student from the dataset
student = Student.sample(1, random_state=42)

student
# Out:
#       Marital status  Application mode  Application order  Course
# 1255               4                12                  1       8  \
#
#       Daytime/evening attendance  Previous qualification  Nacionality
# 1255                           1                       1            1  \
#
#       Mother's qualification  Father's qualification  Mother's occupation
# 1255                       3                       1                    6  \
#
#       ...  Curricular units 2nd sem (credited)
# 1255  ...                                    0  \
#
#       Curricular units 2nd sem (enrolled)
# 1255                                    6  \
#
#       Curricular units 2nd sem (evaluations)
# 1255                                      16  \
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)
# 1255                                    1                              10.0  \
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate
# ...

# %% [markdown]
# # Histogram - Visual Representation

# %%
sns.set_theme(style = 'darkgrid')
Student.hist(bins=10, figsize=(40, 35), grid=True, legend=None);
